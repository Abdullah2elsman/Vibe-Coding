# %%
import requests
import os
from dotenv import load_dotenv

# %%
load_dotenv()

open_router_key = os.getenv("OPENROUTER_API_KEY")

headers = {
    "Authorization": f"Bearer {open_router_key}",
    "Content-Type": "application/json"
}

model = "nvidia/nemotron-3-super-120b-a12b:free"

url = "https://openrouter.ai/api/v1/chat/completions"
payload = {
    "model": model,
    "messages": [
        {
            "role": "user",
            "content": "Explain JS in one sentence"
            }
    ]
}

# %%
response = requests.post(url, headers=headers, json=payload)

# %%
print(response.json()['choices'][0]['message']['content'])
# Out:
# JavaScript is a dynamic programming language primarily used to create interactive effects within web browsers, but also runs on servers and other environments via platforms like Node.js.
